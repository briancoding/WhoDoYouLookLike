# %% [markdown]
# <a href="https://colab.research.google.com/github/briancoding/WhoDoYouLookLike/blob/main/YOLO%EC%82%AC%EC%9A%A9%ED%95%B4%EC%84%9C_%EC%82%AC%EB%9E%8C%EC%9D%B8%EC%8B%9D%ED%95%98%EB%8A%94_%EB%AA%A8%EB%8D%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.0-89-g540ef0d torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅

# %%
# Unzip my train_data.zip file 
# !unzip -q ../train_data.zip -d ../

# %%
# Change path in coco128.yaml

# %%
# Training data

# %%
# Train YOLOv5s on COCO_train for 3 epochs
# !python train.py --img 640 --batch 2 --epochs 60 --data mycustom.yaml --weights yolov5x.pt --nosave --cache
# Out:
# train: weights=yolov5x.pt, cfg=, data=mycustom.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=60, batch_size=2, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-89-g540ef0d torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
#predict my video

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source ../p1.mp4
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=../p1.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-89-g540ef0d torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86173414 parameters, 0 gradients, 204.0 GFLOPs
# video 1/1 (1/214) /content/p1.mp4: 640x384 4 humans, Done. (0.159s)
# video 1/1 (2/214) /content/p1.mp4: 640x384 4 humans, Done. (0.139s)
# video 1/1 (3/214) /content/p1.mp4: 640x384 4 humans, Done. (0.135s)
# video 1/1 (4/214) /content/p1.mp4: 640x384 4 humans, Done. (0.137s)
# video 1/1 (5/214) /content/p1.mp4: 640x384 4 humans, Done. (0.139s)
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source ../p2.mp4
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=../p2.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-89-g540ef0d torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86173414 parameters, 0 gradients, 204.0 GFLOPs
# video 1/1 (1/356) /content/p2.mp4: 384x640 1 human, Done. (0.154s)
# video 1/1 (2/356) /content/p2.mp4: 384x640 1 human, Done. (0.140s)
# video 1/1 (3/356) /content/p2.mp4: 384x640 1 human, Done. (0.139s)
# video 1/1 (4/356) /content/p2.mp4: 384x640 2 humans, Done. (0.143s)
# video 1/1 (5/356) /content/p2.mp4: 384x640 3 humans, Done. (0.145s)
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source ../p3.mp4
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=../p3.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-89-g540ef0d torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86173414 parameters, 0 gradients, 204.0 GFLOPs
# video 1/1 (1/132) /content/p3.mp4: 480x640 Done. (0.205s)
# video 1/1 (2/132) /content/p3.mp4: 480x640 Done. (0.188s)
# video 1/1 (3/132) /content/p3.mp4: 480x640 Done. (0.189s)
# video 1/1 (4/132) /content/p3.mp4: 480x640 Done. (0.195s)
# video 1/1 (5/132) /content/p3.mp4: 480x640 1 human, Done. (0.198s)
# video 1/1 (6/132) /content/p3.mp4: 480x640 2 humans, Done. (0.197s)
# ...
